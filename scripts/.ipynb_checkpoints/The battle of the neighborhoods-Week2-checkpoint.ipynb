# %% [markdown]
# # The Battle of the neighborhoods

# %% [markdown]
# ## Table of contents
# * [Introduction](#introduction)
# * [Data](#data)
# * [Methodology](#methodology)
# * [Analysis](#analysis)
# * [Results and Discussion](#results)
# * [Conclusion](#conclusion)

# %% [markdown]
# ## Introduction:  <a name="introduction"></a>

# %% [markdown]
# A young adult is in the process of making a decision of where to buy a property to live there but is undecided on in which city and neighborhood should he buy it. He currently wants to compare and have a recommendation about neighborhoods in two cities in South America where he has family: Santiago de Chile, Chile and Cali, Colombia, specifically in the communes of Ñuñoa and #22 respectively.

# %% [markdown]
# This kind of problem of deciding where to buy is very important since the price of a property is higher than other kind of purchases and people usually get indebted for many years. The place where you will live for many or some years can determine the time you take to get to work or study, the perceived security, food you can get by foot or in the surroundings and in summary the quality of life.
# In this sense the aspects that matter most are

# %% [markdown]
# ## Data <a name="data"></a>

# %% [markdown]
# Information about neighborhoods about commune 22 in Cali can be found in https://es.wikipedia.org/wiki/Comuna_22_(Cali)
# Information about neighborhoods in Ñuñoa, Chile can be found in https://es.wikipedia.org/wiki/%C3%91u%C3%B1oa. Since both links only provide information about the name of the Neighborhoods location data will be retrieved from geocoder library: https://geocoder.readthedocs.io/index.html.

# %% [markdown]
# Information for the recommended neighborhoods will be fetch from the Foursquare API using the _explore_ endpoint to get an idea about the nearby venues and later classify it.
#
# >`https://api.foursquare.com/v2/venues/`**explore**`?client_id=`**CLIENT_ID**`&client_secret=`**CLIENT_SECRET**`&ll=`**LATITUDE**`,`**LONGITUDE**`&v=`**VERSION**`&limit=`**LIMIT**
#
# _tips_ endpoint to get reviews about the spots:
# > `https://api.foursquare.com/v2/venues/`**VENUE_ID**`/tips?client_id=`**CLIENT_ID**`&client_secret=`**CLIENT_SECRET**`&v=`**VERSION**`&limit=`**LIMIT**
#
# and _likes_ endpoint for how users qualify them:
# > `https://api.foursquare.com/v2/venues/`**VENUE_ID**`/likes?client_id=`**CLIENT_ID**`&client_secret=`**CLIENT_SECRET**`&v=`**VERSION**`&limit=`**LIMIT**

# %% [markdown]
# #### Examples of the venues near Santiago de Chile using _explore_ endpoint

# %%
CLIENT_ID = '1CG02IBFH3BMIUN3FX43OFI3KMTM2FD00ESGHSGP23ODY2M2' # your Foursquare ID
CLIENT_SECRET = 'PRD3I02CL3KM5I5YU4TZ5HWFBEHTX4S0F5WDUND2EB5EEOLR' # your Foursquare Secret
VERSION = '20200719'
LIMIT = 30
radius = 200

# %%
latitude = -33.459229
longitude = -70.645348
url = 'https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&ll={},{}&v={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, radius, LIMIT)
requests.get(url).json()["response"]['groups'][0]['items']
# Out:
# [{'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4de6d11381dce8f797695d66',
#    'name': 'Tostaduria Mataquito',
#    'location': {'address': 'Avenida Manuel Antonio Matta 918',
#     'crossStreet': 'Chiloé',
#     'lat': -33.45922918090518,
#     'lng': -70.64644575119019,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': -33.45922918090518,
#       'lng': -70.64644575119019}],
#     'distance': 101,
#     'cc': 'CL',
#     'city': 'Santiago de Chile',
#     'state': 'Metropolitana de Santiago de Chile',
#     'country': 'Chile',
#     'formattedAddress': ['Avenida Manuel Antonio Matta 918 (Chiloé)',
#      'Santiago de Chile',
#      'Metropolitana de Santiago de Chile',
#      'Chile']},
#    'categories': [{'id': '4bf58dd8d48988d1f9941735',
#      'name': 'Food & Drink Shop',
#      'pluralName': 'Food & Drink Shops',
#      'shortName': 'Food & Drink',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/foodanddrink_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4de6d11381dce8f797695d66-0'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4faad746e4b0af50a800c891',
#    'name': 'Amasandería San Sebastián',
#    'location': {'address': 'Santa Rosa 1142',
#     'lat': -33.45918747581599,
#     'lng': -70.6432395137617,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': -33.45918747581599,
#       'lng': -70.6432395137617}],
#     'distance': 195,
#     'cc': 'CL',
#     'city': 'Santiago de Chile',
#     'state': 'Metropolitana de Santiago de Chile',
#     'country': 'Chile',
#     'formattedAddress': ['Santa Rosa 1142',
#      'Santiago Centro',
#      'Metropolitana de Santiago de Chile',
#      'Chile']},
#    'categories': [{'id': '4bf58dd8d48988d16a941735',
#      'name': 'Bakery',
#      'pluralName': 'Bakeries',
#      'shortName': 'Bakery',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4faad746e4b0af50a800c891-1'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '571f9cbe498e5e10221185e1',
#    'name': 'Calavera Bar',
#    'location': {'address': 'San Francisco 1080',
#     'crossStreet': 'Manuel Antonio Matta',
#     'lat': -33.458811869788654,
#     'lng': -70.64530747121933,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': -33.458811869788654,
#       'lng': -70.64530747121933}],
#     'distance': 46,
#     'cc': 'CL',
#     'city': 'Santiago de Chile',
#     'state': 'Metropolitana de Santiago de Chile',
#     'country': 'Chile',
#     'formattedAddress': ['San Francisco 1080 (Manuel Antonio Matta)',
#      'Santiago de Chile',
#      'Metropolitana de Santiago de Chile',
#      'Chile']},
#    'categories': [{'id': '52e81612bcbc57f1066b79f1',
#      'name': 'Bistro',
#      'pluralName': 'Bistros',
#      'shortName': 'Bistro',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-571f9cbe498e5e10221185e1-2'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4e2464f2922e11c006655847',
#    'name': 'Mister Tutto',
#    'location': {'address': 'Av Matta 902',
#     'crossStreet': 'Chiloé',
#     'lat': -33.459256033408316,
#     'lng': -70.64632773399353,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': -33.459256033408316,
#       'lng': -70.64632773399353}],
#     'distance': 91,
#     'cc': 'CL',
#     'city': 'Santiago de Chile',
#     'state': 'Metropolitana de Santiago de Chile',
#     'country': 'Chile',
#     'formattedAddress': ['Av Matta 902 (Chiloé)',
#      'Santiago de Chile',
#      'Metropolitana de Santiago de Chile',
#      'Chile']},
#    'categories': [{'id': '4d4ae6fc7a7b7dea34424761',
#      'name': 'Fried Chicken Joint',
#      'pluralName': 'Fried Chicken Joints',
#      'shortName': 'Fried Chicken',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/friedchicken_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4e2464f2922e11c006655847-3'}]

# %% [markdown]
# Now let's obtain venues near Ñuñoa

# %%
import requests # library to handle requests
import numpy as np # library to handle data in a vectorized manner
import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
import json # library to handle JSON files
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        #Explore the venue
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
        results = requests.get(url).json()["response"]['groups'][0]['items']
    
        #Get likes
        url = 'https://api.foursquare.com/v2/venues/{}/likes?client_id={}&client_secret={}&ll={},{}&v={}&radius={}&limit={}'.format(smartfit_id, CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, radius, LIMIT)
        likesCount = requests.get(url).json()["response"]["likes"]["count"]
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['id'], 
            likesCount,
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue',  
                  'Venue Id',   
                  'Venue Likes', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
getNearbyVenues(names=['Ñuñoa'],
                                   latitudes= [-33.454],
                                   longitudes= [-70.604]
                                  )
# Out:
# Ñuñoa
#    Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0         Ñuñoa                -33.454                 -70.604
# 1         Ñuñoa                -33.454                 -70.604
# 2         Ñuñoa                -33.454                 -70.604
# 3         Ñuñoa                -33.454                 -70.604
# 4         Ñuñoa                -33.454                 -70.604
# 5         Ñuñoa                -33.454                 -70.604
# 6         Ñuñoa                -33.454                 -70.604
# 7         Ñuñoa                -33.454                 -70.604
# 8         Ñuñoa                -33.454                 -70.604
# 9         Ñuñoa                -33.454                 -70.604
# 10        Ñuñoa                -33.454                 -70.604
# 11        Ñuñoa                -33.454                 -70.604
# 12        Ñuñoa                -33.454                 -70.604
# 13        Ñuñoa                -33.454                 -70.604
# 14        Ñuñoa                -33.454                 -70.604
# 15        Ñuñoa                -33.454                 -70.604
# 16        Ñuñoa                -33.454                 -70.604
# 17        Ñuñoa                -33.454                 -70.604
# 18        Ñuñoa                -33.454                 -70.604
# 5        -70.605081         Chinese Restaurant
# 6        -70.605463                Pastry Shop
# 7        -70.604861  South American Restaurant
# 8        -70.604947              Jewelry Store
# 9        -70.605426                     Bakery
# 10       -70.605649                  Pet Store
# 11       -70.603400                     Bakery
# 12       -70.607641                      Trail
# 13       -70.602818                Pizza Place
# 14       -70.605826                  BBQ Joint
# 15       -70.607508                        Bar
# 16       -70.600806             Farmers Market
# 17       -70.606220               Cupcake Shop
# 18       -70.600470                        Spa
# 19       -70.601753     Furniture / Home Store
# 20       -70.602795                Yoga Studio
# 21       -70.607319       Fast Food Restaurant
# 22       -70.605413                Pizza Place
# 23       -70.609261        Fried Chicken Joint
# 24       -70.605814         Chinese Restaurant
# 25       -70.603268                   Boutique
# 26       -70.600326             Ice Cream Shop
# 27       -70.605143         Chinese Restaurant
# 28       -70.606896                Coffee Shop
# 29       -70.601139                        Gym

# %% [markdown]
# The above data shows several categories of venues. At a first glance seems a very diverse spot.

# %% [markdown]
# #### Using Foursquare _likes_ endpoint to get the likes of a spot

# %% [markdown]
# We can get the likes of a spot such as the gym _SmartFit_

# %%
smartfit_id = "563b24c2cd1065db1bcea099"
url = 'https://api.foursquare.com/v2/venues/{}/likes?client_id={}&client_secret={}&ll={},{}&v={}&radius={}&limit={}'.format(smartfit_id, CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, radius, LIMIT)
requests.get(url).json()["response"]["likes"]["count"]
# Out:
# {'count': 70,
#  'summary': '70 Likes',
#  'items': [{'id': '89088221',
#    'firstName': 'Jose Luis',
#    'lastName': 'A',
#    'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#     'suffix': '/89088221_Zxirn8zo_8u8FgQhs8Gp8r8gycDyvEXFHQXYz1HK-zqUo3bdcS1h8siJ9NXmAiqHYQsa8zVUa.jpg'}},
#   {'id': '10773874',
#    'firstName': 'Anastasia',
#    'lastName': 'V',
#    'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#     'suffix': '/LYACG3LHBZ3SAYZQ.jpg'}},
#   {'id': '22415610',
#    'firstName': 'Andrés',
#    'lastName': 'M',
#    'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#     'suffix': '/22415610_Pcmw4wEF_EWLXQiKYzB6UN9e4kublZdI03gjspbc-Iwql804f4nB0yZdb2X1uVNVB_fgCVvxd.jpg'}},
#   {'id': '8779302',
#    'firstName': 'Tomas',
#    'lastName': 'S',
#    'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#     'suffix': '/4KOWSI2RDTXYAQ1I.jpg'}},
#   {'id': '170711583',
#    'firstName': 'Esteban',
#    'lastName': 'F',
#    'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#     'suffix': '/170711583-CVCYJAK5MS4JXDVB.jpg'}},
#   {'id': '40421800',
#    'firstName': 'Pablo',
#    'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#     'suffix': '/40421800-4T0SEDDP44LJTMNT.jpg'}},
#   {'id': '489838178',
#    'firstName': 'Elias',
#    'lastName': 'R',
#    'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#     'suffix': '/489838178_bRFeuwr3_y3WigffUjqRSTJ-_-hHrE95HRugFZ1xmWM4HbOQ7ZWoI2kdpwVWgy6p6UxGlkokh.jpg'}},
#   {'id': '395775',
#    'firstName': 'Sergio',
#    'lastName': 'C',
#    'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#     'suffix': '/395775-V0WU0DVDBRSVLTYQ.jpg'}},
#   {'id': '37337553',
#    'firstName': 'Carla',
#    'lastName': 'L',
#    'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#     'suffix': '/XJ3IADXGFXE5II40.jpg'}},
#   {'id': '8886592',
#    'firstName': 'Dafne Camila',
#    'lastName': 'K',
#    'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#     'suffix': '/SW2IBFQS0EXSSZC1.jpg'}},
#   {'id': '5273246',
#    'firstName': 'Álvaro',
#    'lastName': 'A',
#    'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#     'suffix': '/5273246_sE9ZvdtQ_hL5y26NoJwfS34ZadQ2pOJtHR_lp7G61azZNyGB1D_e5CRGBaCRwONc9-aqb71QP.jpg'}},
#   {'id': '47963221',
#    'firstName': 'Bastian',
#    'lastName': 'G',
#    'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#     'suffix': '/blank_boy.png',
#     'default': True}},
#   {'id': '424076207',
#    'firstName': 'Marjorie',
#    'lastName': 'C',
#    'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#     'suffix': '/424076207_0r9Ape8d_JEhrelL8s-9KVbjTjXLGopQVyxYXIulamHec6eBM240VI4WiRd7KApnd17P3WIeS.jpg'}},
#   {'id': '19910094',
#    'firstName': 'Joao',
#    'lastName': 'G',
#    'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#     'suffix': '/FYRSDSEHYZAVYZO1.jpg'}},
#   {'id': '343206449',
#    'firstName': 'Cristopher',
#    'lastName': 'R',
#    'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#     'suffix': '/343206449_k4fPv1Im_ozU1KbLDhcEs7uDwT8-o8XKS-A4qDVLItkVwNlXUOO5RLJTWPKN8zge_DzY5iq1s.jpg'}},
#   {'id': '11415366',
#    'firstName': 'Pancho',
#    'lastName': 'L',
#    'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#     'suffix': '/H5V5UNLXDTADFQGG.jpg'}},
#   {'id': '61042189',
#    'firstName': 'Paolo',
#    'lastName': 'L',
#    'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#     'suffix': '/WIQNYL1PORRDOI3T.jpg'}},
#   {'id': '61499211',
#    'firstName': 'Sergio',
#    'lastName': 'S',
#    'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#     'suffix': '/61499211_PvxQYHZ9_4vFVFH-2hB3c2OGtKRzlHwnS1QP5EZd9XL2fNdTsGIHAIOI_ublh-OdjfTmXflhP.jpg'}},
#   {'id': '398947491',
#    'firstName': 'Sandra',
#    'lastName': 'I',
#    'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#     'suffix': '/398947491_tI1Op0il_GJXt4nceG_sX594Jhxt7iHioIf2si19fJBvo4JvoR91UpkjbbZmUA-fKirSZ7qF_.jpg'}},
#   {'id': '59240016',
#    'firstName': 'Javier',
#    'lastName': 'B',
#    'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#     'suffix': '/GQRYX23EUWEXFEVJ.jpg'}},
#   {'id': '20893434',
#    'firstName': 'Rolando',
#    'lastName': 'S',
#    'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#     'suffix': '/0OWBGCLP0WPZVGGV.jpg'}},
#   {'id': '8947666',
#    'firstName': 'Hector',
#    'lastName': 'A',
#    'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#     'suffix': '/8947666_6wyS9Zyu_zVA9zvMnhlZ0ofEhrUO0wx_uz0qF5KtDzOPVNHGeEI30OPGDRRf_L50KwdJ9EAAL.jpg'}},
#   {'id': '18735298',
#    'firstName': 'Claudio',
#    'lastName': 'C',
#    'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#     'suffix': '/18735298_ZBoCDDMT_MJeFz4IsqeG80ED-60RJ1sc56r2XX7Ro21PIoauEHqvvTsu5lJMc_NQ8OFMATeDR.jpg'}},
#   {'id': '1732204',
#    'firstName': 'Roberto',
#    'lastName': 'S',
#    'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#     'suffix': '/FVDMHG2SGZLEB144.jpg'}},
#   {'id': '4462084',
#    'firstName': 'Rene',
#    'lastName': 'B',
#    'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#     'suffix': '/4462084-2HGEOW3RMDLRXWX5.jpg'}},
#   {'id': '5648702',
#    'firstName': 'Rodrigo',
#    'lastName': 'S',
#    'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#     'suffix': '/1DR1QWZKS1GTBHSI.jpg'}}]}

# %% [markdown]
# ## Methodology <a name="methodology"></a>

# %% [markdown]
# Explore the data available from

# %% [markdown]
# ## Analysis <a name="analysis"></a>

# %% [markdown]
# ## Results and Discussion <a name="results"></a>

# %% [markdown]
# ## Conclusion <a name="conclusion"></a>
